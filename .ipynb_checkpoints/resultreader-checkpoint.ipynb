# %%
#!usr/bin/python

"""
This script takes the output from a hyperopt.py run (dump.txt) and 
analyzes the contents (parameters and performance) 
"""
# Out:
# '\nThis script takes the output from a hyperopt.py run (dump.txt) and \nanalyzes the contents (parameters and performance) \n'

# %%
import os

# %%
""" #CLEANUP
if len(sys.argv) < 3:
    print("please specify the input file (whole path)\n and the name of the output file.")
    sys.exit()
"""
#infile = sys.argv[1]
#infile = "../grid_search_1k/dump.txt"
#infile = "../grid_search_5k/dump.txt"
#infile = "../grid_search_10k/dump.txt"
#infile = "../grid_search_2_1k/dump.txt"
infile = "../grid_search_2_5k/dump.txt"


#outfile = "./log/results/"+sys.argv[2]
#outfile = "./log/results/grid_search_1k_results.csv"
#outfile = "./log/results/grid_search_5k_results.csv"
#outfile = "./log/results/grid_search_10k_results.csv"
#outfile = "./log/results/grid_search_2_1k_results.csv"
outfile = "./log/results/grid_search_2_5k_results.csv"

# %%
run_to_config = {}
run_to_performance = {}

with open(infile, "r") as f:
    runcount = 0
    run = {} # temporary dict
    for line in f:
        if line == "\n":
            run_to_config[runcount]= run # add the block of specs to the internal representation of results
            runcount += 1
            run = {} # prepare for the next block of specs
        else: 
            line = line.rstrip()
            kv = line.split("\t")
            kv[0] = kv[0].rstrip() # get rid of spaces between key and value
            try:
                run[kv[0]] = float(kv[1]) # add key-value pair
            except ValueError:
                run[kv[0]] = kv[1] # for the flattening parameter
            if kv[0] == "sp_diff":
                print
                run_to_performance[runcount] = float(kv[1])

# %%
ranked_runs = sorted(run_to_performance, key=run_to_performance.get, reverse=True)
with open(outfile, "w") as f:
    if   outfile[-3:] == "csv": sep = ","
    elif outfile[-3:] == "tsv": sep = "\t"
    elif outfile[-3:] == "txt": sep = "   \t"
    else:                       sep = " "
        
    f.write("score"+sep+"KC_factor"+sep+"projections"+sep+"hash_dims"+sep+"flattening"+"\n")
    for run in ranked_runs:
        line = str(run_to_performance[run])+sep+\
               str(run_to_config[run]["KC_factor"])+sep+\
               str(run_to_config[run]["projections"])+sep+\
               str(run_to_config[run]["hash_dims"])+sep+\
               str(run_to_config[run]["flattening"])+"\n"
        f.write(line)
        print(line.rstrip())
    print("number of runs: ",len(ranked_runs))
# Out:
# 0.08578,2.0,6.0,320.0,log10
# 0.08015,1.0,6.0,120.0,log2
# 0.07918,8.0,6.0,320.0,log
# 0.07801,8.0,10.0,320.0,log10
# 0.07498,2.0,10.0,80.0,log
# 0.0706,8.0,18.0,320.0,log2
# 0.07054,6.0,8.0,240.0,log2
# 0.06999,4.0,8.0,640.0,log2
# 0.06977,4.0,16.0,480.0,log10
# 0.06968,8.0,10.0,320.0,log2
# 0.06957,6.0,14.0,240.0,log
# 0.06859,4.0,8.0,640.0,log10
# 0.06819,2.0,18.0,160.0,log10
# 0.06746,4.0,12.0,640.0,log
# 0.06707,2.0,16.0,80.0,log10
# 0.06691,8.0,12.0,320.0,log
# 0.06688,6.0,14.0,240.0,log2
# 0.06673,2.0,10.0,160.0,log2
# 0.06646,6.0,10.0,720.0,log
# 0.06644,6.0,12.0,480.0,log10
# 0.06595,6.0,18.0,720.0,log10
# 0.06578,1.0,12.0,120.0,log2
# 0.06532,8.0,6.0,640.0,log10
# 0.0652,4.0,8.0,320.0,log10
# 0.06508,4.0,16.0,160.0,log
# 0.06505,8.0,14.0,640.0,log10
# 0.065,8.0,12.0,320.0,log10
# 0.06411,4.0,10.0,480.0,log
# 0.064,6.0,6.0,480.0,log10
# 0.0639,2.0,12.0,320.0,log2
# 0.06383,4.0,6.0,480.0,log
# 0.06365,6.0,10.0,960.0,log10
# 0.06356,4.0,12.0,480.0,log
# 0.0634,8.0,18.0,640.0,log2
# 0.06298,6.0,8.0,960.0,log2
# 0.06234,2.0,18.0,80.0,log10
# 0.06216,4.0,14.0,160.0,log
# 0.06191,2.0,16.0,160.0,log10
# 0.06174,8.0,14.0,320.0,log
# 0.06169,6.0,14.0,960.0,log2
# 0.06146,2.0,8.0,320.0,log2
# 0.06134,2.0,18.0,240.0,log2
# 0.06113,6.0,16.0,1200.0,log2
# 0.06109,4.0,12.0,160.0,log
# 0.06104,8.0,16.0,640.0,log2
# 0.0604,1.0,8.0,160.0,log
# 0.06032,6.0,8.0,960.0,log10
# 0.06022,8.0,6.0,640.0,log
# 0.05985,8.0,10.0,640.0,log
# 0.05964,2.0,14.0,80.0,log10
# 0.05939,8.0,16.0,640.0,log10
# 0.05929,6.0,16.0,240.0,log
# 0.05905,8.0,14.0,960.0,log10
# 0.059,1.0,14.0,120.0,log2
# 0.05874,1.0,14.0,200.0,log10
# 0.0587,8.0,12.0,960.0,log2
# 0.05852,1.0,14.0,160.0,log
# 0.05851,4.0,18.0,480.0,log
# 0.0585,8.0,14.0,1600.0,log2
# 0.05841,2.0,10.0,160.0,log10
# 0.0576,8.0,16.0,1280.0,log2
# 0.05756,2.0,6.0,160.0,log2
# 0.05747,4.0,16.0,480.0,log2
# 0.05706,8.0,16.0,320.0,log2
# 0.05683,6.0,14.0,720.0,log
# 0.05655,6.0,16.0,720.0,log2
# 0.05622,8.0,6.0,1600.0,log2
# 0.05611,4.0,6.0,640.0,log
# 0.0561,4.0,10.0,480.0,log10
# 0.05606,6.0,10.0,1200.0,log
# 0.05592,6.0,14.0,960.0,log10
# 0.05586,8.0,10.0,640.0,log2
# 0.05573,4.0,12.0,480.0,log10
# 0.05566,6.0,12.0,960.0,log2
# 0.0554,4.0,18.0,160.0,log
# 0.05531,4.0,14.0,480.0,log
# 0.05509,2.0,12.0,400.0,log2
# 0.05497,6.0,6.0,960.0,log10
# 0.05484,8.0,6.0,1280.0,log10
# 0.05471,4.0,14.0,800.0,log2
# 0.05468,2.0,12.0,240.0,log
# 0.05458,6.0,10.0,480.0,log2
# 0.05457,6.0,18.0,960.0,log
# 0.05446,4.0,8.0,320.0,log2
# 0.05432,6.0,16.0,960.0,log
# 0.05431,8.0,8.0,320.0,log2
# 0.0543,4.0,6.0,320.0,log10
# 0.05418,2.0,10.0,320.0,log2
# 0.05416,8.0,8.0,960.0,log2
# 0.05413,6.0,16.0,960.0,log10
# 0.05409,1.0,8.0,160.0,log10
# 0.05406,2.0,14.0,320.0,log
# 0.05403,2.0,8.0,400.0,log
# 0.054,8.0,6.0,320.0,log10
# 0.05389,2.0,6.0,80.0,log
# 0.05389,4.0,10.0,320.0,log10
# 0.05385,4.0,8.0,160.0,log
# 0.05378,8.0,8.0,320.0,log10
# 0.05362,1.0,10.0,80.0,log
# 0.05354,6.0,16.0,480.0,log10
# 0.05353,4.0,14.0,640.0,log2
# 0.05348,2.0,16.0,320.0,log10
# 0.05339,1.0,14.0,40.0,log2
# 0.0533,6.0,6.0,720.0,log
# 0.0531,6.0,6.0,1200.0,log
# 0.05308,1.0,18.0,160.0,log
# 0.05307,4.0,6.0,640.0,log2
# 0.05301,6.0,8.0,480.0,log
# 0.05297,1.0,16.0,200.0,log10
# 0.05285,6.0,8.0,1200.0,log10
# 0.05281,8.0,18.0,1280.0,log2
# 0.05269,8.0,12.0,640.0,log2
# 0.05266,2.0,6.0,320.0,log2
# 0.05262,6.0,6.0,720.0,log2
# 0.0526,6.0,14.0,960.0,log
# 0.05255,4.0,10.0,640.0,log10
# 0.05247,6.0,8.0,480.0,log2
# 0.05236,8.0,8.0,1280.0,log10
# 0.05229,8.0,10.0,960.0,log2
# 0.05222,2.0,6.0,240.0,log10
# 0.05219,4.0,18.0,320.0,log
# 0.05215,6.0,8.0,240.0,log10
# 0.05202,8.0,16.0,320.0,log
# 0.05201,4.0,6.0,320.0,log2
# 0.05199,8.0,18.0,640.0,log
# 0.05194,6.0,6.0,960.0,log
# 0.05192,2.0,16.0,240.0,log
# 0.05187,8.0,6.0,960.0,log2
# 0.05185,8.0,14.0,320.0,log10
# 0.05183,8.0,8.0,640.0,log10
# 0.05182,6.0,18.0,1200.0,log
# 0.05176,8.0,14.0,1280.0,log2
# 0.05163,2.0,6.0,160.0,log
# 0.05156,8.0,16.0,1600.0,log2
# 0.05146,6.0,12.0,720.0,log
# 0.05128,6.0,16.0,480.0,log2
# 0.05125,2.0,18.0,320.0,log10
# 0.05114,6.0,12.0,480.0,log2
# 0.05098,6.0,16.0,480.0,log
# 0.05091,2.0,8.0,240.0,log2
# 0.05077,4.0,18.0,640.0,log2
# 0.05075,6.0,12.0,960.0,log
# 0.05072,8.0,12.0,1280.0,log
# 0.05069,4.0,10.0,160.0,log10
# 0.05065,2.0,14.0,240.0,log2
# 0.05044,2.0,10.0,240.0,log2
# 0.05044,4.0,6.0,800.0,log10
# 0.05043,4.0,6.0,480.0,log10
# 0.05042,2.0,18.0,320.0,log2
# 0.05034,2.0,16.0,240.0,log2
# 0.05033,8.0,8.0,960.0,log
# 0.05031,6.0,14.0,480.0,log2
# 0.05028,6.0,16.0,240.0,log2
# 0.05025,4.0,10.0,320.0,log2
# 0.05013,4.0,16.0,160.0,log10
# 0.0501,6.0,10.0,720.0,log10
# 0.05009,8.0,6.0,960.0,log10
# 0.04997,8.0,6.0,1600.0,log
# 0.04995,8.0,12.0,960.0,log10
# 0.04985,8.0,12.0,640.0,log10
# 0.04978,6.0,10.0,480.0,log
# 0.04967,4.0,10.0,160.0,log2
# 0.04964,8.0,10.0,960.0,log10
# 0.04959,6.0,10.0,240.0,log2
# 0.04945,8.0,6.0,640.0,log2
# 0.04941,4.0,14.0,320.0,log
# 0.04938,8.0,14.0,960.0,log
# 0.04934,1.0,10.0,160.0,log
# 0.04931,6.0,10.0,720.0,log2
# 0.04931,6.0,10.0,480.0,log10
# 0.04928,8.0,8.0,640.0,log2
# 0.04921,8.0,18.0,1280.0,log10
# 0.04914,8.0,10.0,1280.0,log10
# 0.04902,8.0,6.0,1600.0,log10
# 0.04882,8.0,14.0,1600.0,log10
# 0.0487,4.0,16.0,320.0,log2
# 0.04859,4.0,6.0,800.0,log2
# 0.04854,8.0,6.0,1280.0,log
# 0.04837,6.0,8.0,1200.0,log
# 0.04836,8.0,18.0,1280.0,log
# 0.04832,2.0,10.0,320.0,log
# 0.04827,6.0,12.0,1200.0,log2
# 0.04824,8.0,16.0,1600.0,log
# 0.04814,2.0,14.0,160.0,log
# 0.04808,8.0,10.0,1600.0,log
# 0.04807,2.0,18.0,400.0,log10
# 0.04794,4.0,12.0,320.0,log10
# 0.04793,2.0,16.0,160.0,log
# 0.04787,8.0,8.0,1600.0,log2
# 0.04782,6.0,16.0,720.0,log10
# 0.04777,2.0,12.0,160.0,log
# 0.04776,8.0,16.0,1280.0,log
# 0.04775,4.0,18.0,160.0,log2
# 0.04752,6.0,6.0,960.0,log2
# 0.04745,6.0,18.0,960.0,log10
# 0.04744,4.0,18.0,640.0,log
# 0.04742,4.0,6.0,640.0,log10
# 0.04734,1.0,14.0,160.0,log2
# 0.04722,4.0,6.0,320.0,log
# 0.0472,8.0,8.0,960.0,log10
# 0.04687,2.0,14.0,240.0,log
# 0.04686,2.0,18.0,240.0,log
# 0.04683,6.0,6.0,1200.0,log10
# 0.04677,6.0,8.0,720.0,log2
# 0.04672,8.0,12.0,960.0,log
# 0.0467,2.0,8.0,160.0,log10
# 0.04665,6.0,8.0,480.0,log10
# 0.04663,6.0,14.0,1200.0,log
# 0.04651,8.0,14.0,640.0,log2
# 0.04637,8.0,8.0,1280.0,log
# 0.04618,4.0,6.0,480.0,log2
# 0.04613,8.0,14.0,960.0,log2
# 0.04607,6.0,10.0,240.0,log10
# 0.04604,8.0,18.0,1600.0,log2
# 0.046,4.0,8.0,480.0,log10
# 0.04598,8.0,18.0,320.0,log
# 0.04596,1.0,14.0,120.0,log
# 0.04594,4.0,16.0,640.0,log
# 0.04591,1.0,10.0,160.0,log10
# 0.04586,4.0,8.0,160.0,log10
# 0.04584,6.0,10.0,1200.0,log10
# 0.04583,8.0,14.0,1600.0,log
# 0.04571,8.0,10.0,1280.0,log2
# 0.04568,2.0,12.0,240.0,log2
# 0.04566,6.0,6.0,480.0,log2
# 0.04516,4.0,18.0,320.0,log2
# 0.04493,8.0,12.0,1600.0,log
# 0.04486,4.0,14.0,640.0,log
# 0.04477,4.0,10.0,320.0,log
# 0.04468,1.0,8.0,200.0,log2
# 0.04446,8.0,12.0,1600.0,log2
# 0.04444,1.0,16.0,200.0,log2
# 0.04444,2.0,16.0,160.0,log2
# 0.04436,6.0,18.0,960.0,log2
# 0.04435,8.0,6.0,1280.0,log2
# 0.04434,8.0,14.0,1280.0,log
# 0.04426,2.0,10.0,160.0,log
# 0.04424,6.0,8.0,720.0,log
# 0.044,8.0,14.0,1280.0,log10
# 0.04391,4.0,14.0,480.0,log10
# 0.04383,6.0,12.0,1200.0,log10
# 0.04375,2.0,6.0,240.0,log2
# 0.04371,6.0,12.0,960.0,log10
# 0.04367,8.0,10.0,1600.0,log10
# 0.04355,4.0,16.0,640.0,log10
# 0.04343,1.0,6.0,200.0,log
# 0.04342,4.0,12.0,800.0,log
# 0.04341,1.0,8.0,80.0,log10
# 0.04327,6.0,6.0,720.0,log10
# 0.04326,6.0,12.0,720.0,log10
# 0.04314,8.0,18.0,960.0,log2
# 0.04308,6.0,16.0,1200.0,log10
# 0.04302,4.0,14.0,480.0,log2
# 0.04295,4.0,14.0,320.0,log2
# 0.04293,8.0,18.0,960.0,log
# 0.04292,2.0,16.0,400.0,log
# 0.04263,6.0,16.0,960.0,log2
# 0.04262,4.0,8.0,800.0,log2
# 0.04261,8.0,12.0,640.0,log
# 0.04252,2.0,6.0,400.0,log
# 0.04245,6.0,18.0,1200.0,log10
# 0.04223,6.0,16.0,240.0,log10
# 0.04219,6.0,18.0,480.0,log10
# 0.04216,1.0,6.0,200.0,log10
# 0.04207,8.0,12.0,1280.0,log10
# 0.04202,1.0,8.0,200.0,log
# 0.04199,8.0,16.0,1600.0,log10
# 0.04172,4.0,12.0,160.0,log10
# 0.04167,6.0,10.0,960.0,log2
# 0.04153,1.0,12.0,80.0,log
# 0.04148,6.0,14.0,480.0,log10
# 0.04145,8.0,8.0,1280.0,log2
# 0.04138,8.0,8.0,1600.0,log
# 0.04131,6.0,16.0,720.0,log
# 0.0413,6.0,10.0,960.0,log
# 0.04124,6.0,16.0,1200.0,log
# 0.04123,4.0,6.0,160.0,log2
# 0.04121,6.0,8.0,960.0,log
# 0.04106,1.0,14.0,200.0,log2
# 0.04097,8.0,16.0,960.0,log
# 0.04097,6.0,6.0,1200.0,log2
# 0.04089,2.0,6.0,400.0,log10
# 0.04089,6.0,12.0,240.0,log10
# 0.04078,8.0,14.0,640.0,log
# 0.04075,8.0,12.0,1280.0,log2
# 0.04067,6.0,14.0,720.0,log2
# 0.04054,6.0,8.0,720.0,log10
# 0.04054,8.0,12.0,1600.0,log10
# 0.04042,4.0,18.0,160.0,log10
# 0.0404,6.0,12.0,240.0,log
# 0.04037,2.0,12.0,320.0,log10
# 0.04033,4.0,16.0,480.0,log
# 0.0403,8.0,10.0,640.0,log10
# 0.04024,8.0,18.0,1600.0,log
# 0.04019,8.0,12.0,320.0,log2
# 0.04016,2.0,18.0,160.0,log2
# 0.04002,4.0,10.0,640.0,log
# 0.04001,2.0,14.0,240.0,log10
# 0.04001,8.0,18.0,1600.0,log10
# 0.03997,2.0,12.0,240.0,log10
# 0.03994,4.0,18.0,640.0,log10
# 0.03992,1.0,14.0,40.0,log
# 0.03986,1.0,14.0,80.0,log10
# 0.03986,4.0,14.0,800.0,log10
# 0.0398,2.0,8.0,240.0,log
# 0.03977,2.0,12.0,320.0,log
# 0.03976,2.0,12.0,400.0,log10
# 0.03971,2.0,14.0,400.0,log
# 0.03968,2.0,8.0,80.0,log10
# 0.03957,2.0,8.0,320.0,log10
# 0.03957,2.0,12.0,160.0,log10
# 0.03952,4.0,14.0,160.0,log2
# 0.03936,6.0,18.0,240.0,log2
# 0.03929,8.0,10.0,960.0,log
# 0.03918,4.0,8.0,640.0,log
# 0.03918,8.0,8.0,1600.0,log10
# 0.03914,2.0,6.0,320.0,log
# 0.03911,6.0,12.0,720.0,log2
# 0.039,4.0,10.0,640.0,log2
# 0.03891,8.0,10.0,1280.0,log
# 0.03885,6.0,10.0,1200.0,log2
# 0.03878,6.0,6.0,480.0,log
# 0.03873,6.0,8.0,240.0,log
# 0.03872,6.0,18.0,480.0,log2
# 0.03871,1.0,16.0,80.0,log10
# 0.03869,4.0,18.0,480.0,log2
# 0.03856,4.0,12.0,480.0,log2
# 0.03855,8.0,10.0,320.0,log
# 0.03849,6.0,18.0,1200.0,log2
# 0.03841,1.0,6.0,120.0,log10
# 0.03837,2.0,14.0,160.0,log2
# 0.03807,2.0,14.0,80.0,log
# 0.03802,4.0,16.0,320.0,log10
# 0.03798,2.0,12.0,80.0,log10
# 0.03798,8.0,18.0,960.0,log10
# 0.0378,8.0,16.0,1280.0,log10
# 0.03779,1.0,6.0,200.0,log2
# 0.03775,2.0,18.0,240.0,log10
# 0.03765,2.0,18.0,400.0,log
# 0.03744,6.0,14.0,480.0,log
# 0.03722,2.0,14.0,80.0,log2
# 0.03715,6.0,18.0,720.0,log
# 0.03715,4.0,14.0,320.0,log10
# 0.03706,4.0,12.0,640.0,log2
# 0.03704,4.0,6.0,800.0,log
# 0.03699,1.0,12.0,200.0,log10
# 0.03694,2.0,18.0,80.0,log2
# 0.03684,8.0,6.0,320.0,log2
# 0.03683,2.0,8.0,400.0,log10
# 0.03682,4.0,14.0,800.0,log
# 0.03667,4.0,12.0,800.0,log10
# 0.03666,6.0,18.0,480.0,log
# 0.03625,6.0,12.0,1200.0,log
# 0.03623,4.0,12.0,640.0,log10
# 0.03594,8.0,16.0,960.0,log2
# 0.03587,2.0,16.0,320.0,log
# 0.03583,2.0,16.0,400.0,log2
# 0.0357,4.0,10.0,800.0,log10
# 0.03563,4.0,16.0,640.0,log2
# 0.0356,2.0,18.0,320.0,log
# 0.03554,4.0,10.0,800.0,log
# 0.03549,4.0,18.0,800.0,log2
# 0.03546,6.0,14.0,1200.0,log2
# 0.03525,8.0,6.0,960.0,log
# 0.03524,4.0,14.0,640.0,log10
# 0.0352,8.0,18.0,640.0,log10
# 0.03504,4.0,8.0,480.0,log2
# 0.03492,1.0,12.0,200.0,log2
# 0.03482,4.0,18.0,320.0,log10
# 0.03461,1.0,10.0,200.0,log
# 0.03459,4.0,10.0,800.0,log2
# 0.03455,2.0,14.0,400.0,log2
# 0.03452,1.0,8.0,160.0,log2
# 0.03439,2.0,12.0,400.0,log
# 0.03437,4.0,16.0,800.0,log
# 0.03428,4.0,8.0,800.0,log
# 0.03426,1.0,18.0,120.0,log
# 0.03413,6.0,8.0,1200.0,log2
# 0.03387,2.0,8.0,160.0,log2
# 0.03378,1.0,8.0,200.0,log10
# 0.03358,6.0,12.0,480.0,log
# 0.03355,1.0,6.0,160.0,log2
# 0.03347,1.0,16.0,200.0,log
# 0.03327,1.0,10.0,120.0,log
# 0.03308,1.0,12.0,160.0,log10
# 0.03299,2.0,10.0,400.0,log10
# 0.03295,1.0,12.0,120.0,log
# 0.03281,1.0,16.0,120.0,log2
# 0.0328,2.0,8.0,160.0,log
# 0.03276,8.0,18.0,320.0,log10
# 0.03264,2.0,6.0,400.0,log2
# 0.03244,2.0,16.0,400.0,log10
# 0.03223,8.0,16.0,960.0,log10
# 0.03216,4.0,8.0,320.0,log
# 0.03212,1.0,6.0,160.0,log
# 0.03209,2.0,16.0,240.0,log10
# 0.03194,4.0,8.0,480.0,log
# 0.03183,2.0,8.0,80.0,log
# 0.03178,8.0,8.0,320.0,log
# 0.03169,6.0,12.0,240.0,log2
# 0.03167,8.0,10.0,1600.0,log2
# 0.03159,6.0,14.0,1200.0,log10
# 0.03133,1.0,14.0,80.0,log2
# 0.03133,6.0,18.0,240.0,log10
# 0.03092,2.0,8.0,400.0,log2
# 0.03083,4.0,16.0,800.0,log2
# 0.03082,6.0,6.0,240.0,log
# 0.0308,6.0,14.0,720.0,log10
# 0.03067,1.0,18.0,40.0,log2
# 0.03047,1.0,18.0,40.0,log
# 0.03046,8.0,8.0,640.0,log
# 0.03002,6.0,14.0,240.0,log10
# 0.02984,2.0,10.0,400.0,log2
# 0.02982,4.0,8.0,800.0,log10
# 0.02974,1.0,14.0,120.0,log10
# 0.02964,2.0,6.0,160.0,log10
# 0.0295,1.0,10.0,120.0,log2
# 0.0295,2.0,14.0,320.0,log2
# 0.02946,2.0,18.0,160.0,log
# 0.0294,1.0,16.0,40.0,log10
# 0.02933,1.0,16.0,120.0,log10
# 0.02927,1.0,12.0,120.0,log10
# 0.029,1.0,10.0,40.0,log2
# 0.02896,8.0,16.0,640.0,log
# 0.02891,1.0,18.0,160.0,log2
# 0.02855,2.0,10.0,320.0,log10
# 0.02836,6.0,18.0,240.0,log
# 0.02817,4.0,18.0,480.0,log10
# 0.02811,6.0,6.0,240.0,log10
# 0.02803,6.0,18.0,720.0,log2
# 0.02799,1.0,18.0,160.0,log10
# 0.02774,8.0,14.0,320.0,log2
# 0.02769,4.0,18.0,800.0,log
# 0.02758,1.0,8.0,80.0,log2
# 0.02733,4.0,16.0,320.0,log
# 0.0267,4.0,18.0,800.0,log10
# 0.02661,6.0,10.0,240.0,log
# 0.0266,2.0,6.0,240.0,log
# 0.02601,1.0,10.0,80.0,log2
# 0.02594,2.0,14.0,400.0,log10
# 0.02577,4.0,6.0,160.0,log
# 0.0257,4.0,10.0,480.0,log2
# 0.02516,2.0,18.0,400.0,log2
# 0.02491,4.0,14.0,160.0,log10
# 0.02438,1.0,12.0,160.0,log
# 0.02386,6.0,6.0,240.0,log2
# 0.02377,2.0,6.0,80.0,log2
# 0.02362,4.0,10.0,160.0,log
# 0.02351,4.0,6.0,160.0,log10
# 0.02272,1.0,16.0,160.0,log
# 0.02176,1.0,16.0,160.0,log10
# 0.02174,4.0,16.0,800.0,log10
# 0.02156,8.0,16.0,320.0,log10
# 0.02152,2.0,8.0,320.0,log
# 0.02124,1.0,8.0,120.0,log2
# 0.02105,2.0,16.0,80.0,log
# 0.02081,4.0,12.0,800.0,log2
# 0.02055,2.0,10.0,400.0,log
# 0.0205,2.0,12.0,80.0,log2
# 0.02046,4.0,16.0,160.0,log2
# 0.02038,1.0,10.0,80.0,log10
# 0.01989,4.0,12.0,320.0,log
# 0.01986,1.0,18.0,120.0,log2
# 0.01981,1.0,18.0,80.0,log10
# 0.0197,1.0,14.0,160.0,log10
# 0.01948,1.0,8.0,40.0,log
# 0.01939,1.0,18.0,120.0,log10
# 0.01917,2.0,14.0,320.0,log10
# 0.0184,1.0,12.0,160.0,log2
# 0.01838,1.0,16.0,80.0,log2
# 0.01813,2.0,8.0,80.0,log2
# 0.01791,2.0,10.0,240.0,log
# 0.01765,2.0,6.0,80.0,log10
# 0.01748,4.0,8.0,160.0,log2
# 0.01689,4.0,12.0,160.0,log2
# 0.01675,1.0,16.0,160.0,log2
# 0.01654,4.0,12.0,320.0,log2
# 0.01531,2.0,14.0,160.0,log10
# 0.01529,1.0,16.0,80.0,log
# 0.01527,1.0,18.0,200.0,log
# 0.01507,1.0,12.0,80.0,log10
# 0.01479,1.0,18.0,200.0,log2
# 0.01478,2.0,18.0,80.0,log
# 0.0142,2.0,16.0,320.0,log2
# 0.01367,1.0,12.0,80.0,log2
# 0.01178,1.0,18.0,80.0,log
# 0.01178,1.0,6.0,80.0,log10
# 0.01177,2.0,10.0,80.0,log10
# 0.01081,1.0,6.0,40.0,log10
# 0.01062,2.0,12.0,80.0,log
# 0.01058,1.0,6.0,120.0,log
# 0.00936,1.0,14.0,80.0,log
# 0.00849,1.0,6.0,80.0,log
# 0.00837,1.0,10.0,200.0,log10
# 0.00767,1.0,12.0,40.0,log2
# 0.00765,1.0,10.0,160.0,log2
# 0.00757,1.0,14.0,200.0,log
# 0.00746,2.0,12.0,160.0,log2
# 0.0069,2.0,10.0,240.0,log10
# 0.00594,2.0,8.0,240.0,log10
# 0.00562,1.0,8.0,80.0,log
# 0.00456,1.0,18.0,80.0,log2
# 0.00431,2.0,16.0,80.0,log2
# 0.00416,1.0,12.0,200.0,log
# 0.00408,2.0,10.0,80.0,log2
# 0.00216,1.0,10.0,200.0,log2
# 0.00063,1.0,10.0,120.0,log10
# -0.00075,1.0,16.0,120.0,log
# -0.00077,1.0,6.0,80.0,log2
# -0.00105,1.0,16.0,40.0,log2
# -0.00108,1.0,8.0,120.0,log10
# -0.00213,1.0,6.0,160.0,log10
# -0.00467,1.0,8.0,120.0,log
# -0.00653,1.0,16.0,40.0,log
# -0.00689,1.0,18.0,40.0,log10
# -0.00706,1.0,18.0,200.0,log10
# -0.00713,1.0,8.0,40.0,log2
# -0.01283,1.0,10.0,40.0,log
# -0.016,1.0,8.0,40.0,log10
# -0.01916,1.0,12.0,40.0,log10
# -0.02304,1.0,10.0,40.0,log10
# -0.02852,1.0,6.0,40.0,log
# -0.02912,1.0,14.0,40.0,log10
# -0.03074,1.0,6.0,40.0,log2
# -0.03526,1.0,12.0,40.0,log
# number of runs:  525
