# %%
#!usr/bin/python

"""
This script takes the output from a hyperopt.py run (dump.txt) and 
analyzes the contents (parameters and performance) 
"""
# Out:
# '\nThis script takes the output from a hyperopt.py run (dump.txt) and \nanalyzes the contents (parameters and performance) \n'

# %%
import os

# %%
""" #CLEANUP
if len(sys.argv) < 3:
    print("please specify the input file (whole path)\n and the name of the output file.")
    sys.exit()
"""
#infile = sys.argv[1]
infile = "../grid_search_1k/dump.txt"
#infile = "../grid_search_5k/dump.txt"
#infile = "../grid_search_10k/dump.txt"


#outfile = "./log/results/"+sys.argv[2]
outfile = "./log/results/grid_search_1k_results.csv"
#outfile = "./log/results/grid_search_5k_results.csv"
#outfile = "./log/results/grid_search_10k_results.csv"

# %%
run_to_config = {}
run_to_performance = {}

with open(infile, "r") as f:
    runcount = 0
    run = {} # temporary dict
    for line in f:
        if line == "\n":
            run_to_config[runcount]= run # add the block of specs to the internal representation of results
            runcount += 1
            run = {} # prepare for the next block of specs
        else: 
            line = line.rstrip()
            kv = line.split("\t")
            kv[0] = kv[0].rstrip() # get rid of spaces between key and value
            try:
                run[kv[0]] = float(kv[1]) # add key-value pair
            except ValueError:
                run[kv[0]] = kv[1] # for the flattening parameter
            if kv[0] == "sp_diff":
                print
                run_to_performance[runcount] = float(kv[1])

# %%
ranked_runs = sorted(run_to_performance, key=run_to_performance.get, reverse=True)
with open(outfile, "w") as f:
    if   outfile[-3:] == "csv": sep = ","
    elif outfile[-3:] == "tsv": sep = "\t"
    elif outfile[-3:] == "txt": sep = "   \t"
    else:                       sep = " "
        
    f.write("score"+sep+"KC_factor"+sep+"projections"+sep+"hash_dims"+sep+"flattening"+"\n")
    for run in ranked_runs:
        line = str(run_to_performance[run])+sep+\
               str(run_to_config[run]["KC_factor"])+sep+\
               str(run_to_config[run]["projections"])+sep+\
               str(run_to_config[run]["hash_dims"])+sep+\
               str(run_to_config[run]["flattening"])
        print(line)
        f.write(line+"\n")
# Out:
# 0.08387,4.0,4.0,320.0,log2
# 0.07175,4.0,8.0,160.0,log
# 0.06733,1.0,6.0,80.0,log2
# 0.06619,4.0,6.0,160.0,log2
# 0.06564,4.0,6.0,160.0,log10
# 0.06535,4.0,8.0,480.0,log2
# 0.06423,4.0,8.0,160.0,log2
# 0.06208,1.0,10.0,80.0,log
# 0.06176,4.0,4.0,160.0,log2
# 0.06127,4.0,10.0,320.0,log
# 0.06028,4.0,6.0,160.0,log
# 0.06016,4.0,8.0,160.0,log10
# 0.05957,4.0,10.0,160.0,log10
# 0.05753,4.0,4.0,640.0,log
# 0.05678,1.0,6.0,200.0,log
# 0.0558,4.0,10.0,480.0,log10
# 0.05508,4.0,10.0,640.0,log10
# 0.05494,4.0,2.0,160.0,log10
# 0.05386,4.0,10.0,480.0,log2
# 0.05373,4.0,10.0,160.0,log2
# 0.05349,4.0,4.0,480.0,log10
# 0.05334,4.0,4.0,320.0,log
# 0.05255,4.0,4.0,320.0,log10
# 0.05244,4.0,10.0,640.0,log2
# 0.05207,4.0,4.0,160.0,log
# 0.05196,4.0,8.0,640.0,log10
# 0.05156,1.0,4.0,120.0,log
# 0.05123,1.0,6.0,160.0,log
# 0.05056,4.0,6.0,480.0,log2
# 0.05011,4.0,6.0,320.0,log2
# 0.04994,1.0,10.0,200.0,log10
# 0.04979,4.0,10.0,320.0,log2
# 0.04967,1.0,8.0,200.0,log
# 0.04964,4.0,4.0,480.0,log
# 0.04939,4.0,6.0,800.0,log2
# 0.04909,4.0,8.0,320.0,log
# 0.04906,4.0,8.0,320.0,log10
# 0.04842,4.0,10.0,160.0,log
# 0.04803,1.0,8.0,120.0,log10
# 0.04795,4.0,10.0,800.0,log
# 0.04761,4.0,8.0,640.0,log2
# 0.04754,4.0,6.0,640.0,log10
# 0.04742,4.0,6.0,480.0,log10
# 0.04738,4.0,8.0,480.0,log10
# 0.04701,4.0,6.0,320.0,log10
# 0.04655,1.0,10.0,160.0,log
# 0.04635,1.0,10.0,120.0,log10
# 0.04626,4.0,8.0,800.0,log10
# 0.04581,1.0,6.0,80.0,log10
# 0.04489,4.0,2.0,160.0,log2
# 0.04402,1.0,6.0,120.0,log
# 0.04396,4.0,10.0,640.0,log
# 0.04344,4.0,10.0,800.0,log2
# 0.04343,4.0,6.0,320.0,log
# 0.04342,4.0,10.0,480.0,log
# 0.04299,4.0,6.0,800.0,log10
# 0.04284,1.0,8.0,80.0,log2
# 0.04245,4.0,8.0,480.0,log
# 0.0424,4.0,6.0,640.0,log
# 0.04193,4.0,10.0,800.0,log10
# 0.04177,1.0,10.0,160.0,log10
# 0.04146,4.0,2.0,160.0,log
# 0.04143,4.0,2.0,320.0,log2
# 0.04137,4.0,6.0,480.0,log
# 0.04126,4.0,4.0,800.0,log10
# 0.04099,1.0,4.0,120.0,log10
# 0.0401,4.0,6.0,800.0,log
# 0.03977,1.0,10.0,200.0,log2
# 0.03961,4.0,8.0,320.0,log2
# 0.03929,4.0,8.0,800.0,log2
# 0.03864,1.0,4.0,120.0,log2
# 0.03805,1.0,10.0,160.0,log2
# 0.03755,1.0,8.0,160.0,log2
# 0.0372,4.0,4.0,480.0,log2
# 0.03561,4.0,2.0,800.0,log2
# 0.03499,1.0,10.0,40.0,log2
# 0.03423,4.0,6.0,640.0,log2
# 0.03386,4.0,8.0,640.0,log
# 0.0335,4.0,4.0,800.0,log2
# 0.03347,4.0,4.0,160.0,log10
# 0.03341,4.0,2.0,320.0,log
# 0.03281,4.0,2.0,480.0,log
# 0.03269,1.0,6.0,200.0,log2
# 0.03219,1.0,10.0,120.0,log
# 0.03211,4.0,4.0,640.0,log2
# 0.03181,1.0,4.0,200.0,log10
# 0.03127,4.0,8.0,800.0,log
# 0.03099,4.0,10.0,320.0,log10
# 0.03072,1.0,8.0,80.0,log
# 0.03042,1.0,10.0,40.0,log10
# 0.03032,1.0,4.0,40.0,log
# 0.02921,1.0,4.0,200.0,log2
# 0.02866,1.0,4.0,160.0,log
# 0.02832,1.0,4.0,80.0,log10
# 0.02776,1.0,6.0,160.0,log10
# 0.02705,4.0,4.0,800.0,log
# 0.02682,1.0,8.0,200.0,log10
# 0.02664,1.0,8.0,160.0,log10
# 0.02622,4.0,2.0,640.0,log
# 0.02611,4.0,4.0,640.0,log10
# 0.0261,1.0,2.0,120.0,log2
# 0.02599,1.0,2.0,80.0,log10
# 0.02505,1.0,4.0,160.0,log2
# 0.02432,4.0,2.0,640.0,log2
# 0.02422,1.0,6.0,120.0,log10
# 0.02394,1.0,8.0,200.0,log2
# 0.02371,4.0,2.0,800.0,log
# 0.02346,4.0,2.0,480.0,log10
# 0.02246,1.0,10.0,40.0,log
# 0.02172,1.0,2.0,160.0,log2
# 0.02087,1.0,8.0,120.0,log
# 0.02078,1.0,4.0,200.0,log
# 0.01908,1.0,8.0,160.0,log
# 0.01852,1.0,10.0,120.0,log2
# 0.01612,1.0,8.0,40.0,log2
# 0.01591,1.0,4.0,80.0,log
# 0.01533,1.0,2.0,120.0,log10
# 0.01449,1.0,4.0,160.0,log10
# 0.01448,4.0,2.0,480.0,log2
# 0.01432,1.0,2.0,160.0,log
# 0.01234,1.0,2.0,40.0,log10
# 0.01168,4.0,2.0,320.0,log10
# 0.01121,4.0,2.0,800.0,log10
# 0.0086,1.0,6.0,120.0,log2
# 0.00847,1.0,4.0,80.0,log2
# 0.00813,1.0,8.0,120.0,log2
# 0.00792,1.0,2.0,80.0,log2
# 0.0075,1.0,10.0,80.0,log2
# 0.0064,1.0,6.0,200.0,log10
# 0.00636,4.0,2.0,640.0,log10
# 0.0054,1.0,6.0,80.0,log
# 0.00508,1.0,8.0,40.0,log
# 0.00353,1.0,6.0,160.0,log2
# -5e-05,1.0,10.0,200.0,log
# -0.00035,1.0,4.0,40.0,log2
# -0.00045,1.0,6.0,40.0,log
# -0.00063,1.0,8.0,40.0,log10
# -0.00191,1.0,2.0,120.0,log
# -0.00191,1.0,6.0,40.0,log10
# -0.00223,1.0,2.0,200.0,log10
# -0.00304,1.0,2.0,40.0,log
# -0.00572,1.0,10.0,80.0,log10
# -0.01357,1.0,8.0,80.0,log10
# -0.014,1.0,2.0,200.0,log
# -0.01449,1.0,2.0,80.0,log
# -0.01454,1.0,2.0,200.0,log2
# -0.0206,1.0,2.0,160.0,log10
# -0.04032,1.0,2.0,40.0,log2
# -0.04841,1.0,6.0,40.0,log2
# -0.05468,1.0,4.0,40.0,log10
